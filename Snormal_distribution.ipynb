# %%
from scipy import stats

# %%
stats.norm.cdf(697,711,29)
# Out:
# 0.31463356742704107

# %%
stats.norm.cdf(740,711,29)
# Out:
# 0.8413447460685429

# %%
import pandas as pd
import numpy as np

# %%
beml = pd.read_csv("BEML.csv")

# %%
glaxo = pd.read_csv("GLAXO.csv")

# %%
beml.head()
# Out:
#          Date    Open     High      Low    Last    Close  \
# 0  2010-01-04  1121.0  1151.00  1121.00  1134.0  1135.60
# 1  2010-01-05  1146.8  1149.00  1128.75  1135.0  1134.60
# 2  2010-01-06  1140.0  1164.25  1130.05  1137.0  1139.60
# 3  2010-01-07  1142.0  1159.40  1119.20  1141.0  1144.15
# 4  2010-01-08  1156.0  1172.00  1140.00  1141.2  1144.05
#
#    Total Trade Quantity  Turnover (Lacs)
# 0              101651.0          1157.18
# 1               59504.0           676.47
# 2              128908.0          1482.84
# 3              117871.0          1352.98
# 4              170063.0          1971.42

# %%
glaxo.head()
# Out:
#          Date     Open     High      Low    Last    Close  \
# 0  2010-01-04  1613.00  1629.10  1602.00  1629.0  1625.65
# 1  2010-01-05  1639.95  1639.95  1611.05  1620.0  1616.80
# 2  2010-01-06  1618.00  1644.00  1617.00  1639.0  1638.50
# 3  2010-01-07  1645.00  1654.00  1636.00  1648.0  1648.70
# 4  2010-01-08  1650.00  1650.00  1626.55  1640.0  1639.80
#
#    Total Trade Quantity  Turnover (Lacs)
# 0                9365.0           151.74
# 1               38148.0           622.58
# 2               36519.0           595.09
# 3               12809.0           211.00
# 4               28035.0           459.11

# %%
beml = beml[['Date', 'Close']]
glaxo = glaxo[['Date', 'Close']]

# %%
beml
print(glaxo)
# Out:
#             Date    Close
# 0     2010-01-04  1625.65
# 1     2010-01-05  1616.80
# 2     2010-01-06  1638.50
# 3     2010-01-07  1648.70
# 4     2010-01-08  1639.80
# ...          ...      ...
# 1734  2016-12-26  2723.50
# 1735  2016-12-27  2701.75
# 1736  2016-12-28  2702.15
# 1737  2016-12-29  2727.90
# 1738  2016-12-30  2729.80
#
# [1739 rows x 2 columns]

# %%
glaxo
# Out:
#             Date    Close
# 0     2010-01-04  1625.65
# 1     2010-01-05  1616.80
# 2     2010-01-06  1638.50
# 3     2010-01-07  1648.70
# 4     2010-01-08  1639.80
# ...          ...      ...
# 1734  2016-12-26  2723.50
# 1735  2016-12-27  2701.75
# 1736  2016-12-28  2702.15
# 1737  2016-12-29  2727.90
# 1738  2016-12-30  2729.80
#
# [1739 rows x 2 columns]

# %%
beml.dtypes
# Out:
# Date      object
# Close    float64
# dtype: object

# %%
glaxo.dtypes
# Out:
# Date      object
# Close    float64
# dtype: object

# %%
glaxo = glaxo.set_index(pd.DatetimeIndex(glaxo['Date']))
beml = beml.set_index(pd.DatetimeIndex(beml['Date']))

# %%
glaxo
# Out:
#                   Date    Close
# Date
# 2010-01-04  2010-01-04  1625.65
# 2010-01-05  2010-01-05  1616.80
# 2010-01-06  2010-01-06  1638.50
# 2010-01-07  2010-01-07  1648.70
# 2010-01-08  2010-01-08  1639.80
# ...                ...      ...
# 2016-12-26  2016-12-26  2723.50
# 2016-12-27  2016-12-27  2701.75
# 2016-12-28  2016-12-28  2702.15
# 2016-12-29  2016-12-29  2727.90
# 2016-12-30  2016-12-30  2729.80
#
# [1739 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sn
plt.plot(glaxo.Close);
plt.title("clossing time")
plt.xlabel('Time');
plt.ylabel('Close Price');

# %%
plt.plot(beml.Close);
plt.xlabel('Time');
plt.ylabel('Close');

# %%
glaxo['gain'] = glaxo.Close.pct_change(periods = 1)
beml['gain'] = beml.Close.pct_change(periods = 1)

# %%
glaxo
# Out:
#                   Date    Close      gain
# Date
# 2010-01-04  2010-01-04  1625.65       NaN
# 2010-01-05  2010-01-05  1616.80 -0.005444
# 2010-01-06  2010-01-06  1638.50  0.013422
# 2010-01-07  2010-01-07  1648.70  0.006225
# 2010-01-08  2010-01-08  1639.80 -0.005398
# ...                ...      ...       ...
# 2016-12-26  2016-12-26  2723.50 -0.001283
# 2016-12-27  2016-12-27  2701.75 -0.007986
# 2016-12-28  2016-12-28  2702.15  0.000148
# 2016-12-29  2016-12-29  2727.90  0.009529
# 2016-12-30  2016-12-30  2729.80  0.000697
#
# [1739 rows x 3 columns]

# %%
glaxo = glaxo.dropna()
beml = beml.dropna()

# %%
glaxo
# Out:
#                   Date    Close      gain
# Date
# 2010-01-05  2010-01-05  1616.80 -0.005444
# 2010-01-06  2010-01-06  1638.50  0.013422
# 2010-01-07  2010-01-07  1648.70  0.006225
# 2010-01-08  2010-01-08  1639.80 -0.005398
# 2010-01-11  2010-01-11  1629.45 -0.006312
# ...                ...      ...       ...
# 2016-12-26  2016-12-26  2723.50 -0.001283
# 2016-12-27  2016-12-27  2701.75 -0.007986
# 2016-12-28  2016-12-28  2702.15  0.000148
# 2016-12-29  2016-12-29  2727.90  0.009529
# 2016-12-30  2016-12-30  2729.80  0.000697
#
# [1738 rows x 3 columns]

# %%
plt.figure(figsize = (8, 6));
plt.plot(glaxo.gain);
plt.xlabel('Time');
plt.ylabel('gain');

# %%
plt.figure(figsize = (8, 6));
plt.plot(beml.gain);
plt.xlabel('Time');
plt.ylabel('gain');

# %%
sn.distplot(glaxo.gain, label = 'Glaxo');
plt.xlabel('gain');
plt.ylabel('Density');
plt.legend();
# Out:
# <ipython-input-25-98e2aff39f0d>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(glaxo.gain, label = 'Glaxo');

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.suptitle("Dsitribution",fontsize=15)

sn.distplot(glaxo.gain, label="glaxo")

plt.subplot(1,2,2)

sn.distplot(beml.gain, label="glaxo")
# Out:
# <ipython-input-27-a0915c7bbe8f>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(glaxo.gain, label="glaxo")
# <ipython-input-27-a0915c7bbe8f>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(beml.gain, label="glaxo")
# <Axes: xlabel='gain', ylabel='Density'>

# %%
import pandas as pd
import numpy as np

# %%
beml = pd.read_csv("BEML.csv")

# %%
glaxo = pd.read_csv("GLAXO.csv")

# %%
type(beml)
# Out:
# pandas.core.frame.DataFrame

# %%
beml.head()
# Out:
#          Date    Open     High      Low    Last    Close  \
# 0  2010-01-04  1121.0  1151.00  1121.00  1134.0  1135.60
# 1  2010-01-05  1146.8  1149.00  1128.75  1135.0  1134.60
# 2  2010-01-06  1140.0  1164.25  1130.05  1137.0  1139.60
# 3  2010-01-07  1142.0  1159.40  1119.20  1141.0  1144.15
# 4  2010-01-08  1156.0  1172.00  1140.00  1141.2  1144.05
#
#    Total Trade Quantity  Turnover (Lacs)
# 0              101651.0          1157.18
# 1               59504.0           676.47
# 2              128908.0          1482.84
# 3              117871.0          1352.98
# 4              170063.0          1971.42

# %%
beml = beml[['Date', 'Close']]
glaxo = glaxo[['Date','Close']]

# %%
print(beml.head())
glaxo.head()
# Out:
#          Date    Close
# 0  2010-01-04  1135.60
# 1  2010-01-05  1134.60
# 2  2010-01-06  1139.60
# 3  2010-01-07  1144.15
# 4  2010-01-08  1144.05
#          Date    Close
# 0  2010-01-04  1625.65
# 1  2010-01-05  1616.80
# 2  2010-01-06  1638.50
# 3  2010-01-07  1648.70
# 4  2010-01-08  1639.80

# %%
beml = beml.set_index(pd.DatetimeIndex(beml['Date']))
glaxo = glaxo.set_index(pd.DatetimeIndex(glaxo['Date']))

# %%
print(beml.head())
glaxo.head()
# Out:
#                   Date    Close
# Date
# 2010-01-04  2010-01-04  1135.60
# 2010-01-05  2010-01-05  1134.60
# 2010-01-06  2010-01-06  1139.60
# 2010-01-07  2010-01-07  1144.15
# 2010-01-08  2010-01-08  1144.05
#                   Date    Close
# Date
# 2010-01-04  2010-01-04  1625.65
# 2010-01-05  2010-01-05  1616.80
# 2010-01-06  2010-01-06  1638.50
# 2010-01-07  2010-01-07  1648.70
# 2010-01-08  2010-01-08  1639.80

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.xlabel("Time")
plt.ylabel("Close Time")
plt.plot(glaxo.Close)

# %%
plt.xlabel("Time")
plt.ylabel("close Time")
plt.plot(beml.Close)

# %%
glaxo['gain'] = glaxo.Close.pct_change(periods = 1)
beml['gain'] = beml.Close.pct_change(periods = 1)

# %%
glaxo['gain']
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05   -0.005444
# 2010-01-06    0.013422
# 2010-01-07    0.006225
# 2010-01-08   -0.005398
#                 ...
# 2016-12-26   -0.001283
# 2016-12-27   -0.007986
# 2016-12-28    0.000148
# 2016-12-29    0.009529
# 2016-12-30    0.000697
# Name: gain, Length: 1739, dtype: float64

# %%
glaxo = glaxo.dropna()
beml = beml.dropna()

# %%
glaxo
# Out:
#                   Date    Close      gain
# Date
# 2010-01-05  2010-01-05  1616.80 -0.005444
# 2010-01-06  2010-01-06  1638.50  0.013422
# 2010-01-07  2010-01-07  1648.70  0.006225
# 2010-01-08  2010-01-08  1639.80 -0.005398
# 2010-01-11  2010-01-11  1629.45 -0.006312
# ...                ...      ...       ...
# 2016-12-26  2016-12-26  2723.50 -0.001283
# 2016-12-27  2016-12-27  2701.75 -0.007986
# 2016-12-28  2016-12-28  2702.15  0.000148
# 2016-12-29  2016-12-29  2727.90  0.009529
# 2016-12-30  2016-12-30  2729.80  0.000697
#
# [1738 rows x 3 columns]

# %%
plt.figure(figsize=(10,8))
plt.xlabel("Index")
plt.ylabel("Gain")
plt.plot(beml.index , beml.gain)

# %%
plt.figure(figsize=(10,8))
plt.xlabel("index")
plt.ylabel('gain')
plt.plot(glaxo.index,glaxo.gain)

# %%
beml.plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
beml['gain'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.distplot(beml.gain,label = 'glaxo')
plt.legend()
# Out:
# <ipython-input-24-4b5438a5aaf2>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(beml.gain,label = 'glaxo')

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
plt.suptitle("distribution",fontsize=25)
sns.distplot(beml.gain,label = 'beml')

plt.subplot(1,2,2)
sns.distplot(glaxo.gain,label='glaxo')
# Out:
# <ipython-input-25-43540a0763a6>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(beml.gain,label = 'beml')
# <ipython-input-25-43540a0763a6>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(glaxo.gain,label='glaxo')
# <Axes: xlabel='gain', ylabel='Density'>

# %%
plt.figure(figsize=(10,5))
sns.distplot(glaxo.gain,label='glaxo')
sns.distplot(beml.gain,label='beml')
plt.xlabel("gain")
plt.ylabel("density")
plt.legend()
# Out:
# <ipython-input-31-bd7617913627>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(glaxo.gain,label='glaxo')
# <ipython-input-31-bd7617913627>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(beml.gain,label='beml')

# %%
print(glaxo.gain.mean())
print(glaxo.gain.std())
# Out:
# 0.0003860410825922916
# 0.013360538552253337

# %%
print('mean',round(glaxo.mean(),4))
print("standard deviation",round(glaxo.std(),4))
# Out:
# mean Close    2533.1536
# gain        0.0004
# dtype: float64
# standard deviation Close    540.4415
# gain       0.0134
# dtype: float64
# <ipython-input-34-cac7a3426ac6>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print('mean',round(glaxo.mean(),4))
# <ipython-input-34-cac7a3426ac6>:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print("standard deviation",round(glaxo.std(),4))

# %%
print(beml.gain.mean(),"mean")
print(beml.gain.std(),"standard devuiation")
# Out:
# 0.0002707480790572326 mean
# 0.026430831468474872 standard devuiation

# %%
from scipy import stats

# %%
loc=glaxo.gain.mean()
scale=glaxo.gain.std()
stats.norm.cdf(-0.02,loc,scale)
# Out:
# 0.06352488667177401

# %%
loc=glaxo.gain.mean()
scale=glaxo.gain.std()
1-stats.norm.cdf(0.02,loc,scale)
# Out:
# 0.07104511457618568

# %%
loc=beml.gain.mean()
scale=beml.gain.std()
stats.norm.cdf(-0.02,loc,scale)
# Out:
# 0.22155987503755292

# %%
loc=beml.gain.mean()
scale=beml.gain.std()
1-stats.norm.cdf(0.02,loc,scale)
# Out:
# 0.22769829484075355
